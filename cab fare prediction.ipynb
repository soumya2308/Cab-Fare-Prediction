# %%
# importing libraries

import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("train_cab.csv")

# %%
df
# Out:
#       fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0             4.5  2009-06-15 17:26:21 UTC        -73.844311        40.721319
# 1            16.9  2010-01-05 16:52:16 UTC        -74.016048        40.711303
# 2             5.7  2011-08-18 00:35:00 UTC        -73.982738        40.761270
# 3             7.7  2012-04-21 04:30:42 UTC        -73.987130        40.733143
# 4             5.3  2010-03-09 07:51:00 UTC        -73.968095        40.768008
# ...           ...                      ...               ...              ...
# 16062         6.5  2014-12-12 07:41:00 UTC        -74.008820        40.718757
# 16063        16.1  2009-07-13 07:58:00 UTC        -73.981310        40.781695
# 16064         8.5  2009-11-11 11:19:07 UTC        -73.972507        40.753417
# 16065         8.1  2010-05-11 23:53:00 UTC        -73.957027        40.765945
# 16066         8.5  2011-12-14 06:24:33 UTC        -74.002111        40.729755
#
# ...

# %%
# checking for null values
df.isnull().sum()
# Out:
# fare_amount          24
# pickup_datetime       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# passenger_count      55
# dtype: int64

# %%
df.describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count      16067.000000     16067.000000       16067.000000      16067.000000
# mean         -72.462787        39.914725         -72.462328         39.897906
# std           10.578384         6.826587          10.575062          6.187087
# min          -74.438233       -74.006893         -74.429332        -74.006377
# 25%          -73.992156        40.734927         -73.991182         40.734651
# 50%          -73.981698        40.752603         -73.980172         40.753567
# 75%          -73.966838        40.767381         -73.963643         40.768013
# max           40.766125       401.083332          40.802437         41.366138
#
#        passenger_count
# count     16012.000000
# mean          2.625070
# std          60.844122
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        5345.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16067 entries, 0 to 16066
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fare_amount        16043 non-null  object
#  1   pickup_datetime    16067 non-null  object
#  2   pickup_longitude   16067 non-null  float64
#  3   pickup_latitude    16067 non-null  float64
#  4   dropoff_longitude  16067 non-null  float64
#  5   dropoff_latitude   16067 non-null  float64
#  6   passenger_count    16012 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 878.8+ KB

# %%
# converting fair amount in numeric format 
df["fare_amount"]= pd.to_numeric(df["fare_amount"], errors= "coerce")

# %%
df
# Out:
#        fare_amount          pickup_datetime  pickup_longitude  \
# 0              4.5  2009-06-15 17:26:21 UTC        -73.844311
# 1             16.9  2010-01-05 16:52:16 UTC        -74.016048
# 2              5.7  2011-08-18 00:35:00 UTC        -73.982738
# 3              7.7  2012-04-21 04:30:42 UTC        -73.987130
# 4              5.3  2010-03-09 07:51:00 UTC        -73.968095
# ...            ...                      ...               ...
# 16062          6.5  2014-12-12 07:41:00 UTC        -74.008820
# 16063         16.1  2009-07-13 07:58:00 UTC        -73.981310
# 16064          8.5  2009-11-11 11:19:07 UTC        -73.972507
# 16065          8.1  2010-05-11 23:53:00 UTC        -73.957027
# 16066          8.5  2011-12-14 06:24:33 UTC        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0            40.721319         -73.841610         40.712278              1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16067 entries, 0 to 16066
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fare_amount        16042 non-null  float64
#  1   pickup_datetime    16067 non-null  object
#  2   pickup_longitude   16067 non-null  float64
#  3   pickup_latitude    16067 non-null  float64
#  4   dropoff_longitude  16067 non-null  float64
#  5   dropoff_latitude   16067 non-null  float64
#  6   passenger_count    16012 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 878.8+ KB

# %%
df.describe()
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  16042.000000      16067.000000     16067.000000       16067.000000
# mean      15.015004        -72.462787        39.914725         -72.462328
# std      430.460945         10.578384         6.826587          10.575062
# min       -3.000000        -74.438233       -74.006893         -74.429332
# 25%        6.000000        -73.992156        40.734927         -73.991182
# 50%        8.500000        -73.981698        40.752603         -73.980172
# 75%       12.500000        -73.966838        40.767381         -73.963643
# max    54343.000000         40.766125       401.083332          40.802437
#
#        dropoff_latitude  passenger_count
# count      16067.000000     16012.000000
# mean          39.897906         2.625070
# std            6.187087        60.844122
# min          -74.006377         0.000000
# 25%           40.734651         1.000000
# 50%           40.753567         1.000000
# ...

# %% [markdown]
# # checking for outliers

# %%
df["fare_amount"].quantile(.97)
# Out:
# 38.25400000000009

# %%
df.drop(df[df['fare_amount']  >38].index, inplace = True)

# %%
df
# Out:
#        fare_amount          pickup_datetime  pickup_longitude  \
# 0              4.5  2009-06-15 17:26:21 UTC        -73.844311
# 1             16.9  2010-01-05 16:52:16 UTC        -74.016048
# 2              5.7  2011-08-18 00:35:00 UTC        -73.982738
# 3              7.7  2012-04-21 04:30:42 UTC        -73.987130
# 4              5.3  2010-03-09 07:51:00 UTC        -73.968095
# ...            ...                      ...               ...
# 16062          6.5  2014-12-12 07:41:00 UTC        -74.008820
# 16063         16.1  2009-07-13 07:58:00 UTC        -73.981310
# 16064          8.5  2009-11-11 11:19:07 UTC        -73.972507
# 16065          8.1  2010-05-11 23:53:00 UTC        -73.957027
# 16066          8.5  2011-12-14 06:24:33 UTC        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0            40.721319         -73.841610         40.712278              1.0
# ...

# %%
df.drop(df[df['passenger_count']  <1].index, inplace = True)

# %%
df
# Out:
#        fare_amount          pickup_datetime  pickup_longitude  \
# 0              4.5  2009-06-15 17:26:21 UTC        -73.844311
# 1             16.9  2010-01-05 16:52:16 UTC        -74.016048
# 2              5.7  2011-08-18 00:35:00 UTC        -73.982738
# 3              7.7  2012-04-21 04:30:42 UTC        -73.987130
# 4              5.3  2010-03-09 07:51:00 UTC        -73.968095
# ...            ...                      ...               ...
# 16062          6.5  2014-12-12 07:41:00 UTC        -74.008820
# 16063         16.1  2009-07-13 07:58:00 UTC        -73.981310
# 16064          8.5  2009-11-11 11:19:07 UTC        -73.972507
# 16065          8.1  2010-05-11 23:53:00 UTC        -73.957027
# 16066          8.5  2011-12-14 06:24:33 UTC        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0            40.721319         -73.841610         40.712278              1.0
# ...

# %%
df["passenger_count"].quantile(0.99)
# Out:
# 6.0

# %%
df.drop(df[df['passenger_count']  >6].index, inplace = True)

# %%
df
# Out:
#        fare_amount          pickup_datetime  pickup_longitude  \
# 0              4.5  2009-06-15 17:26:21 UTC        -73.844311
# 1             16.9  2010-01-05 16:52:16 UTC        -74.016048
# 2              5.7  2011-08-18 00:35:00 UTC        -73.982738
# 3              7.7  2012-04-21 04:30:42 UTC        -73.987130
# 4              5.3  2010-03-09 07:51:00 UTC        -73.968095
# ...            ...                      ...               ...
# 16062          6.5  2014-12-12 07:41:00 UTC        -74.008820
# 16063         16.1  2009-07-13 07:58:00 UTC        -73.981310
# 16064          8.5  2009-11-11 11:19:07 UTC        -73.972507
# 16065          8.1  2010-05-11 23:53:00 UTC        -73.957027
# 16066          8.5  2011-12-14 06:24:33 UTC        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0            40.721319         -73.841610         40.712278              1.0
# ...

# %%
df["passenger_count"].describe()
# Out:
# count    15452.000000
# mean         1.650356
# std          1.269555
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          6.000000
# Name: passenger_count, dtype: float64

# %%
df.isnull().sum()
# Out:
# fare_amount          24
# pickup_datetime       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# passenger_count      54
# dtype: int64

# %%
df["fare_amount"].mean()
# Out:
# 10.060240924945122

# %% [markdown]
# # replacing missing values with mean value

# %%
df["fare_amount"].fillna(value=10, inplace= True)

# %%
df.isnull().sum()
# Out:
# fare_amount           0
# pickup_datetime       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# passenger_count      54
# dtype: int64

# %%
df["passenger_count"].fillna(value=2, inplace= True)

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df["fare_amount"].describe()
# Out:
# count    15506.000000
# mean        10.060148
# std          6.215837
# min         -3.000000
# 25%          6.000000
# 50%          8.100000
# 75%         12.000000
# max         38.000000
# Name: fare_amount, dtype: float64

# %%
df.drop(df[df['fare_amount']<=0].index, inplace = True)

# %%
df
# Out:
#        fare_amount          pickup_datetime  pickup_longitude  \
# 0              4.5  2009-06-15 17:26:21 UTC        -73.844311
# 1             16.9  2010-01-05 16:52:16 UTC        -74.016048
# 2              5.7  2011-08-18 00:35:00 UTC        -73.982738
# 3              7.7  2012-04-21 04:30:42 UTC        -73.987130
# 4              5.3  2010-03-09 07:51:00 UTC        -73.968095
# ...            ...                      ...               ...
# 16062          6.5  2014-12-12 07:41:00 UTC        -74.008820
# 16063         16.1  2009-07-13 07:58:00 UTC        -73.981310
# 16064          8.5  2009-11-11 11:19:07 UTC        -73.972507
# 16065          8.1  2010-05-11 23:53:00 UTC        -73.957027
# 16066          8.5  2011-12-14 06:24:33 UTC        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0            40.721319         -73.841610         40.712278              1.0
# ...

# %%
df["fare_amount"].describe()
# Out:
# count    15502.000000
# mean        10.063285
# std          6.213538
# min          0.010000
# 25%          6.000000
# 50%          8.100000
# 75%         12.000000
# max         38.000000
# Name: fare_amount, dtype: float64

# %%
df.drop(df[df['fare_amount']<1].index, inplace = True)

# %%
df.describe()
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  15501.000000      15501.000000     15501.000000       15501.000000
# mean      10.063934        -72.493719        39.934730         -72.487488
# std        6.213213         10.472163         6.767467          10.484726
# min        1.140000        -74.229138       -74.006893         -74.227047
# 25%        6.000000        -73.992318        40.735769         -73.991231
# 50%        8.100000        -73.981938        40.752941         -73.980287
# 75%       12.000000        -73.967701        40.767520         -73.964469
# max       38.000000         40.766125       401.083332          40.802437
#
#        dropoff_latitude  passenger_count
# count      15501.000000     15501.000000
# mean          39.914487         1.651590
# std            6.105376         1.267531
# min          -73.994392         1.000000
# 25%           40.735450         1.000000
# 50%           40.753788         1.000000
# ...

# %%
df.passenger_count= df.passenger_count.astype(int, errors="raise")

# %%
df
# Out:
#        fare_amount          pickup_datetime  pickup_longitude  \
# 0              4.5  2009-06-15 17:26:21 UTC        -73.844311
# 1             16.9  2010-01-05 16:52:16 UTC        -74.016048
# 2              5.7  2011-08-18 00:35:00 UTC        -73.982738
# 3              7.7  2012-04-21 04:30:42 UTC        -73.987130
# 4              5.3  2010-03-09 07:51:00 UTC        -73.968095
# ...            ...                      ...               ...
# 16062          6.5  2014-12-12 07:41:00 UTC        -74.008820
# 16063         16.1  2009-07-13 07:58:00 UTC        -73.981310
# 16064          8.5  2009-11-11 11:19:07 UTC        -73.972507
# 16065          8.1  2010-05-11 23:53:00 UTC        -73.957027
# 16066          8.5  2011-12-14 06:24:33 UTC        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0            40.721319         -73.841610         40.712278                1
# ...

# %% [markdown]
# # converting pickup datetime column into datetime and splitting

# %%
df["pickup_datetime"]= pd.to_datetime(df["pickup_datetime"], errors="coerce")

# %%
df['year'] = [t.year for t in pd.DatetimeIndex(df.pickup_datetime)]
df["month"] = [t.month for t in pd.DatetimeIndex(df.pickup_datetime)]
df["day"] = [t.dayofweek for t in pd.DatetimeIndex(df.pickup_datetime)]
df["hour"] = [t.hour for t in pd.DatetimeIndex(df.pickup_datetime)]
df["min"] = [t.minute for t in pd.DatetimeIndex(df.pickup_datetime)]
df['sec'] = [t.second for t in pd.DatetimeIndex(df.pickup_datetime)]

# %%
df
# Out:
#        fare_amount           pickup_datetime  pickup_longitude  \
# 0              4.5 2009-06-15 17:26:21+00:00        -73.844311
# 1             16.9 2010-01-05 16:52:16+00:00        -74.016048
# 2              5.7 2011-08-18 00:35:00+00:00        -73.982738
# 3              7.7 2012-04-21 04:30:42+00:00        -73.987130
# 4              5.3 2010-03-09 07:51:00+00:00        -73.968095
# ...            ...                       ...               ...
# 16062          6.5 2014-12-12 07:41:00+00:00        -74.008820
# 16063         16.1 2009-07-13 07:58:00+00:00        -73.981310
# 16064          8.5 2009-11-11 11:19:07+00:00        -73.972507
# 16065          8.1 2010-05-11 23:53:00+00:00        -73.957027
# 16066          8.5 2011-12-14 06:24:33+00:00        -74.002111
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0            40.721319         -73.841610         40.712278                1
# ...

# %%
df.drop(["pickup_datetime"], axis=1, inplace = True)

# %%
df
# Out:
#        fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0              4.5        -73.844311        40.721319         -73.841610
# 1             16.9        -74.016048        40.711303         -73.979268
# 2              5.7        -73.982738        40.761270         -73.991242
# 3              7.7        -73.987130        40.733143         -73.991567
# 4              5.3        -73.968095        40.768008         -73.956655
# ...            ...               ...              ...                ...
# 16062          6.5        -74.008820        40.718757         -73.998865
# 16063         16.1        -73.981310        40.781695         -74.014392
# 16064          8.5        -73.972507        40.753417         -73.979577
# 16065          8.1        -73.957027        40.765945         -73.981983
# 16066          8.5        -74.002111        40.729755         -73.983877
#
#        dropoff_latitude  passenger_count    year  month  day  hour   min   sec
# ...

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# year                 1
# month                1
# day                  1
# hour                 1
# min                  1
# sec                  1
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# year                 0
# month                0
# day                  0
# hour                 0
# min                  0
# sec                  0
# dtype: int64

# %%
df.describe()
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  15500.000000      15500.000000     15500.000000       15500.000000
# mean      10.063841        -72.493623        39.934679         -72.487391
# std        6.213403         10.472494         6.767683          10.485057
# min        1.140000        -74.229138       -74.006893         -74.227047
# 25%        6.000000        -73.992319        40.735770         -73.991231
# 50%        8.100000        -73.981935        40.752944         -73.980286
# 75%       12.000000        -73.967700        40.767524         -73.964467
# max       38.000000         40.766125       401.083332          40.802437
#
#        dropoff_latitude  passenger_count          year         month  \
# count      15500.000000     15500.000000  15500.000000  15500.000000
# mean          39.914433         1.651613   2011.716645      6.248194
# std            6.105569         1.267569      1.865908      3.447057
# ...

# %% [markdown]
# # using harvesine formula

# %% [markdown]
# In the dataset we were provided with latitudes and longitudes so we cannot predict distance using that therefore we will have to use harvesian formula and using that we can convert latitudes and longitudes into distance

# %%
from math import *

def haversine(a):
    lon1=a[0]
    lat1=a[1]
    lon2=a[2]
    lat2=a[3]
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c =  2 * asin(sqrt(a))
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

# %%
df['distance'] = df[['pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude']].apply(haversine,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-3222b26c4811> in <module>
# ----> 1 df['distance'] = df[['pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude']].apply(haversine,axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
df

# %%
df.drop(["pickup_longitude","pickup_latitude","dropoff_longitude","dropoff_latitude"], axis=1, inplace= True)

# %%
df

# %%
df["distance"].min()

# %%
df.drop(df[df['distance']==0].index, inplace = True)

# %%
df["distance"].max()

# %%
df.drop(df[df['distance']>30].index, inplace=True)

# %% [markdown]
# # using random forest model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(train.drop(["fare_amount"],axis=1), train["fare_amount"], test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
model.score(x_test, y_test)
# Out:
# 0.8096317423956321

# %%
prediction=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test, prediction)
# Out:
# 0.8000570272689373
